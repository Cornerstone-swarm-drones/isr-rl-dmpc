# %% [markdown]
# # System Overview - ISR-RL-DMPC
#
# High-level overview of the ISR-RL-DMPC framework: reinforcement-learning-based distributed model-predictive control for intelligent surveillance and reconnaissance.

# %%
import importlib
import isr_rl_dmpc

print('Package:', isr_rl_dmpc.__name__)
modules = [name for name in dir(isr_rl_dmpc) if not name.startswith('_')]
print('Available modules:', modules)
